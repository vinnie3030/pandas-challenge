# %%
#import libraries for analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#import csv files for analysis
df_schools = pd.read_csv('PyCitySchools/Resources/schools_complete.csv')
df_students = pd.read_csv('PyCitySchools/Resources/students_complete.csv')


# Combine the data into a single dataset
school_data_complete = pd.merge(df_students , df_schools, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
df_schools.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
df_students.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#Calculate the total number of schools
total_schools=df_schools["school_name"].count()
total_schools

#Calculate the total number of students
total_students=df_students["student_name"].count()
total_students

#Calculate the total budget
total_budget=df_schools["budget"].sum()
total_budget

#Calculate the average math score
avg_math=df_students[("math_score")].mean()
avg_math

#cclculate the average reading score
avg_reading=df_students[("reading_score")].mean()
avg_reading

#Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
overall_avg=((avg_math + avg_reading) /2)
overall_avg

#Calculate the percentage of students with a passing math score (70 or greater)
perc_math_pass=(school_data_complete["math_score"]>70).sum() / school_data_complete["math_score"].count()* 100
perc_math_pass 

#* Calculate the percentage of students with a passing reading score (70 or greater)
perc_reading_pass= (school_data_complete["reading_score"]>70).sum() / school_data_complete["reading_score"].count()* 100
perc_reading_pass

##(student_data["reading_score"]>70).count() *100
# Out:
# 82.97166198621395

# %%
# Creating the District Summery 
District_Summary = pd.DataFrame({"Total Schools":[total_schools], "Total Students":[total_students],"Total Budget":[total_budget],
                        "Average Math Score":[avg_math], "Average Reading Score":[avg_reading], "% Passing Math":[perc_math_pass],
                        "% Passing Reading":[perc_reading_pass],"% Overall Passing Rate":[overall_avg]})
District_Summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       72.392137          82.971662
#
#    % Overall Passing Rate
# 0               80.431606

# %%
#creat a different DF for District Summery to do mapping
District_Summary_DF=pd.DataFrame(District_Summary, columns=["Total Schools","Total Students","Total Budget",
                                "Average Math Score","Average Reading Score","% Passing Math","% Passing Reading",
                                "% Overall Passing Rate"])
District_Summary_DF
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       72.392137          82.971662
#
#    % Overall Passing Rate
# 0               80.431606

# %%
#mapping the District_summery_Df

District_Summary_DF["Total Students"]=District_Summary_DF["Total Students"].map("{:,}".format)
District_Summary_DF["Total Budget"]=District_Summary_DF["Total Budget"].map("{:,}".format)


District_Summary_DF["Average Math Score"]=District_Summary_DF["Average Math Score"].map("{:,.2f}".format)
District_Summary_DF["Average Reading Score"]=District_Summary_DF["Average Reading Score"].map("{:,.2f}".format)
District_Summary_DF["% Passing Math"]=District_Summary_DF["% Passing Math"].map("{:,.2f}".format)
District_Summary_DF["% Passing Reading"]=District_Summary_DF["% Passing Reading"].map("{:,.2f}".format)
District_Summary_DF["% Overall Passing Rate"]=District_Summary_DF["% Overall Passing Rate"].map("{:,.2f}".format)

District_Summary_DF
# Out:
#    Total Schools Total Students Total Budget Average Math Score  \
# 0             15         39,170   24,649,428              78.99
#
#   Average Reading Score % Passing Math % Passing Reading  \
# 0                 81.88          72.39             82.97
#
#   % Overall Passing Rate
# 0                  80.43

# %%
sch_count= len(school_data_complete["school_name"].unique())
sch_count
###school_count= school_data_complete["school_name"].unique() #=== this is just for me to know the Diff the upper cell
#school_count
# Out:
# 15

# %%
#School Name, lets set the schoolName & type col as index 1st
sch_types=df_schools.set_index(["school_name"])["type"]
sch_types.head()
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Name: type, dtype: object

# %%
#Total Students in each school
stu_per_sch=school_data_complete["school_name"].value_counts()
stu_per_sch.head()
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Name: school_name, dtype: int64

# %%
#Total School Budget
sch_budget=school_data_complete.groupby(["school_name"])["budget"].mean()
sch_budget.head()
# Out:
# school_name
# Bailey High School      3124928
# Cabrera High School     1081356
# Figueroa High School    1884411
# Ford High School        1763916
# Griffin High School      917500
# Name: budget, dtype: int64

# %%
#Per Student Budget
per_stu_bud=sch_budget/stu_per_sch
per_stu_bud.head()
# Out:
# Bailey High School      628.0
# Cabrera High School     582.0
# Figueroa High School    639.0
# Ford High School        644.0
# Griffin High School     625.0
# dtype: float64

# %%
#Average Math Score per school
avg_math_perSch=school_data_complete.groupby(["school_name"])["math_score"].mean()
avg_math_perSch.head()
# Out:
# school_name
# Bailey High School      77.048432
# Cabrera High School     83.061895
# Figueroa High School    76.711767
# Ford High School        77.102592
# Griffin High School     83.351499
# Name: math_score, dtype: float64

# %%
#Average Reading Score per school
avg_red_perSch= school_data_complete.groupby(["school_name"])["reading_score"].mean()
avg_red_perSch.head()
# Out:
# school_name
# Bailey High School      81.033963
# Cabrera High School     83.975780
# Figueroa High School    81.158020
# Ford High School        80.746258
# Griffin High School     83.816757
# Name: reading_score, dtype: float64

# %%
#% Passing Math per school 
pas_math_score=school_data_complete.loc[school_data_complete["math_score"]>=70]
pas_math_score

#assign the math scoor by each school
group_math_sch=pas_math_score["school_name"].value_counts()
group_math_sch.head()

percent_math=group_math_sch/stu_per_sch*100
percent_math
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# Name: school_name, dtype: float64

# %%
# % Passing Reading per school
read_score=school_data_complete.loc[school_data_complete["reading_score"]>=70]

#assign the reading scoor by each school
by_read_PerSch= read_score["school_name"].value_counts()
by_read_PerSch.head()

#get the final percentage result
percent_read=by_read_PerSch/stu_per_sch*100
percent_read
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# Name: school_name, dtype: float64

# %%
# % Overall Passing Rate 
overall=percent_math + percent_read/stu_per_sch
overall
# Out:
# Bailey High School       66.696530
# Cabrera High School      94.185705
# Figueroa High School     66.015849
# Ford High School         68.338554
# Griffin High School      93.458542
# Hernandez High School    66.770413
# Holden High School       92.731271
# Huang High School        65.711799
# Johnson High School      66.074611
# Pena High School         94.694331
# Rodriguez High School    66.386652
# Shelton High School      93.921553
# Thomas High School       93.331687
# Wilson High School       93.910004
# Wright High School       93.387006
# Name: school_name, dtype: float64

# %%
#create a new DF for the School_summery
school_summery_df = pd.DataFrame({"School Type":sch_types, "Total Students":stu_per_sch, "Total School Budget":sch_budget
                            ,"Per Student Budget":per_stu_bud ,"Average Math Score" :avg_math_perSch,
                             "Average Reading Score":avg_red_perSch,
                            "% Passing Math":percent_math, "% Passing Reading":percent_read,
                            "% Overall Passing Rate":overall})
school_summery_df.head()
# Out:
#                      School Type  Total Students  Total School Budget  \
# Bailey High School      District            4976              3124928
# Cabrera High School      Charter            1858              1081356
# Figueroa High School    District            2949              1884411
# Ford High School        District            2739              1763916
# Griffin High School      Charter            1468               917500
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School                 628.0           77.048432
# Cabrera High School                582.0           83.061895
# Figueroa High School               639.0           76.711767
# Ford High School                   644.0           77.102592
# Griffin High School                625.0           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963       66.680064
# ...

# %%
# Top Performing Schools By Passing Rate
TopSchool_df=school_summery_df.sort_values(["% Passing Math","% Passing Reading","% Overall Passing Rate" ], 
                                        ascending=False)
TopSchool_df.head()
# Out:
#                     School Type  Total Students  Total School Budget  \
# Pena High School        Charter             962               585858
# Cabrera High School     Charter            1858              1081356
# Wilson High School      Charter            2283              1319574
# Shelton High School     Charter            1761              1056600
# Griffin High School     Charter            1468               917500
#
#                      Per Student Budget  Average Math Score  \
# Pena High School                  609.0           83.839917
# Cabrera High School               582.0           83.061895
# Wilson High School                578.0           83.274201
# Shelton High School               600.0           83.359455
# Griffin High School               625.0           83.351499
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Pena High School                 84.044699       94.594595          95.945946
# ...

# %%
# mapping Top Performing Schools By Passing Rate
TopSchool_df["Total School Budget"]=TopSchool_df["Total School Budget"].map("${:,.2f}".format)
TopSchool_df["Per Student Budget"]=TopSchool_df["Per Student Budget"].map("${:,.2f}".format)

TopSchool_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Pena High School          Charter             962         $585,858.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Wilson High School        Charter            2283       $1,319,574.00
# Shelton High School       Charter            1761       $1,056,600.00
# Griffin High School       Charter            1468         $917,500.00
# Wright High School        Charter            1800       $1,049,400.00
# Thomas High School        Charter            1635       $1,043,130.00
# Holden High School        Charter             427         $248,087.00
# Ford High School         District            2739       $1,763,916.00
# Hernandez High School    District            4635       $3,022,020.00
# Bailey High School       District            4976       $3,124,928.00
# Rodriguez High School    District            3999       $2,547,363.00
# ...

# %%
# Display Bottom 5 Performing Schools By Passing Rate
BottomSchool_df=school_summery_df.sort_values("% Overall Passing Rate")
BottomSchool_df.head(5)
# Out:
#                       School Type  Total Students  Total School Budget  \
# Huang High School        District            2917              1910635
# Figueroa High School     District            2949              1884411
# Johnson High School      District            4761              3094650
# Rodriguez High School    District            3999              2547363
# Bailey High School       District            4976              3124928
#
#                        Per Student Budget  Average Math Score  \
# Huang High School                   655.0           76.629414
# Figueroa High School                639.0           76.711767
# Johnson High School                 650.0           77.072464
# Rodriguez High School               637.0           76.842711
# Bailey High School                  628.0           77.048432
#
#                        Average Reading Score  % Passing Math  \
# Huang High School                  81.182722       65.683922
# ...

# %%
# Math Scores By Grade
#read_scor=school_data_complete.loc[school_data_complete["reading_score"]>=70]
math_9th=df_students.loc[df_students["grade"] == "9th"].groupby(["school_name"])['math_score'].mean()
math_9th.head()
math_10th=df_students.loc[df_students["grade"] == "10th"].groupby(["school_name"])['math_score'].mean()
math_10th.head()
math_11th=df_students.loc[df_students["grade"] == "11th"].groupby(["school_name"])["math_score"].mean()
math_11th.head()
math_12th=df_students.loc[df_students["grade"] == "12th"].groupby(["school_name"])["math_score"].mean()
math_12th.head()

#create a DF for Math Scores by Grade
math_byGrade=pd.DataFrame({"9th":math_9th, "10th": math_10th, "11th":math_11th, "12th":math_12th })
math_byGrade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
# Reading Score By Grade (same as above format)
read_9th=df_students.loc[df_students["grade"] == "9th" ].groupby(["school_name"])["reading_score"].mean()
read_10th=df_students.loc[df_students["grade"] == "10th" ].groupby(["school_name"])["reading_score"].mean()
read_11th=df_students.loc[df_students["grade"] == "11th" ].groupby(["school_name"])["reading_score"].mean()
read_12th=df_students.loc[df_students["grade"] == "12th" ].groupby(["school_name"])["reading_score"].mean()

reading_byGrade=pd.DataFrame({"9th":read_9th,"10th":read_10th, "11th":read_11th, "12th":read_12th })
reading_byGrade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
# Scores By School Spending

# Bin Sizes. 
bins = [0, 550, 600, 650, 700]
group_names = ["<$550", "$550-600", "$600-650", "$650-700"]

school_summery_df["Spending Ranges (Per Student)"]=pd.cut(school_summery_df["Total School Budget"]/school_summery_df["Total Students"]
                                            ,bins , labels=group_names)
school_summery_df.head()
scores_by_sch=school_summery_df .drop(columns=["Total Students", "Total School Budget","School Type", "Per Student Budget"])
scores_by_sch
# Out:
#                        Average Math Score  Average Reading Score  \
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
# Rodriguez High School           76.842711              80.744686
# Shelton High School             83.359455              83.725724
# Thomas High School              83.418349              83.848930
# ...

# %%
# groupby Scores by School Spending
by_spending=scores_by_sch.groupby(["Spending Ranges (Per Student)"])
by_spending.mean()
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$550                                         NaN                    NaN
# $550-600                                83.436210              83.892196
# $600-650                                79.423466              82.044963
# $650-700                                76.959583              81.058567
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$550                                     NaN                NaN
# $550-600                            93.541501          96.459627
# $600-650                            76.832677          86.725974
# $650-700                            66.218444          81.089710
#
#                                % Overall Passing Rate
# Spending Ranges (Per Student)
# <$550                                             NaN
# $550-600                                    93.627108
# ...

# %%
# School Size (same as above)

# Bin sizes.
size_bins = [0, 750, 2500, 7000]
group_names = ["Small (<750)", "Medium (750-2500)", "Large (2500-7000)"]

# %%
school_summery_df["School Size"]=pd.cut(school_summery_df["Total Students"],size_bins , labels=group_names)
                                            
school_summery_df.head(10)


scores_by_sch["School Size"]=pd.cut(school_summery_df["Total Students"],size_bins , labels=group_names)
scores_by_sch.head(10)
# Out:
#                        Average Math Score  Average Reading Score  \
# Bailey High School              77.048432              81.033963
# Cabrera High School             83.061895              83.975780
# Figueroa High School            76.711767              81.158020
# Ford High School                77.102592              80.746258
# Griffin High School             83.351499              83.816757
# Hernandez High School           77.289752              80.934412
# Holden High School              83.803279              83.814988
# Huang High School               76.629414              81.182722
# Johnson High School             77.072464              80.966394
# Pena High School                83.839917              84.044699
#
#                        % Passing Math  % Passing Reading  \
# Bailey High School          66.680064          81.933280
# Cabrera High School         94.133477          97.039828
# Figueroa High School        65.988471          80.739234
# ...

# %%
# groupby Scores by School Size
by_SchoolSize = scores_by_sch.groupby(["School Size"])
by_SchoolSize.mean()
# Out:
#                    Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<750)                83.803279              83.814988       92.505855
# Medium (750-2500)           83.426791              83.908054       93.780112
# Large (2500-7000)           76.956733              80.966636       66.548453
#
#                    % Passing Reading  % Overall Passing Rate
# School Size
# Small (<750)               96.252927               92.731271
# Medium (750-2500)          96.634141               93.841261
# Large (2500-7000)          80.799062               66.570630

# %%
# Scores By School Size (as above)
# Bin Sizes
size_bins = [0, 750, 2500, 7000]
group_names = ["Small (<750)", "Medium (750-2500)", "Large (2500-7000)"]

# %%
school_summery_df["School Size"]=pd.cut(school_summery_df["Total Students"],size_bins , labels=group_names)
                                            
school_summery_df.head()


scores_by_sch["School Size"]=pd.cut(school_summery_df["Total Students"],size_bins , labels=group_names)
scores_by_sch.head()
# Out:
#                       Average Math Score  Average Reading Score  \
# Bailey High School             77.048432              81.033963
# Cabrera High School            83.061895              83.975780
# Figueroa High School           76.711767              81.158020
# Ford High School               77.102592              80.746258
# Griffin High School            83.351499              83.816757
#
#                       % Passing Math  % Passing Reading  \
# Bailey High School         66.680064          81.933280
# Cabrera High School        94.133477          97.039828
# Figueroa High School       65.988471          80.739234
# Ford High School           68.309602          79.299014
# Griffin High School        93.392371          97.138965
#
#                       % Overall Passing Rate Spending Ranges (Per Student)  \
# Bailey High School                 66.696530                      $600-650
# Cabrera High School                94.185705                      $550-600
# ...

# %%
# groupby Scores by School Size
by_schSize = scores_by_sch.groupby(["School Size"])
by_schSize.mean()
# Out:
#                    Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<750)                83.803279              83.814988       92.505855
# Medium (750-2500)           83.426791              83.908054       93.780112
# Large (2500-7000)           76.956733              80.966636       66.548453
#
#                    % Passing Reading  % Overall Passing Rate
# School Size
# Small (<750)               96.252927               92.731271
# Medium (750-2500)          96.634141               93.841261
# Large (2500-7000)          80.799062               66.570630

# %%
# Scores by School Type (as above)
scores_by_type= school_summery_df.drop(columns=["Total Students","Total School Budget", "Per Student Budget"])
scores_by_type.head()
# Out:
#                      School Type  Average Math Score  Average Reading Score  \
# Bailey High School      District           77.048432              81.033963
# Cabrera High School      Charter           83.061895              83.975780
# Figueroa High School    District           76.711767              81.158020
# Ford High School        District           77.102592              80.746258
# Griffin High School      Charter           83.351499              83.816757
#
#                       % Passing Math  % Passing Reading  \
# Bailey High School         66.680064          81.933280
# Cabrera High School        94.133477          97.039828
# Figueroa High School       65.988471          80.739234
# Ford High School           68.309602          79.299014
# Griffin High School        93.392371          97.138965
#
#                       % Overall Passing Rate Spending Ranges (Per Student)  \
# Bailey High School                 66.696530                      $600-650
# ...

# %%
# groupby Scores by School Type
by_schoolType = scores_by_type.groupby(["School Type"])
by_schoolType.mean()
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing Rate
# School Type
# Charter              96.586489               93.702512
# District             80.799062               66.570630

# %%
# Out of 15 schools counting 37,170 students, the Overall Oassing Percentage is 80.43.

# Based on school size, Small sizes (<750 students) perform signifigantly better than larger sized schools (2500 - 6000 students)

# Charter Schools seem to have a much higher Overall Passing Percentage Rate than District schools.  




####  Checked my work against engysamaan's contributions and tweaked where needed.
